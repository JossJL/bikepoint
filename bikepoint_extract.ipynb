# %% [markdown]
# This is the markdown for the bikepoint extract project - after I've written the Python script we will use this

# %% [markdown]
# Set up a virtual environment

# %%
python -m venv .venv
.\.venv\Scripts\activate

# %% [markdown]
# Set up a requirements file using pip freeze

# %%
pip freeze > requirements.txt
